# %%
library(tidyverse)
library(repr)
library(broom)
library(leaps)
library(moderndive)


my_data <- read.csv("paris_weekends.csv")



my_data
# Out:
#      X    realSum  room_type       room_shared room_private person_capacity
# 1     0   536.3967 Entire home/apt False       False        5
# 2     1   290.1016 Private room    False       True         2
# 3     2   445.7545 Entire home/apt False       False        4
# 4     3   211.3431 Private room    False       True         2
# 5     4   266.3342 Entire home/apt False       False        2
# 6     5   345.0927 Entire home/apt False       False        2
# 7     6   387.0351 Entire home/apt False       False        2
# 8     7   247.9262 Entire home/apt False       False        4
# 9     8   527.0761 Entire home/apt False       False        4
# 10    9   193.6341 Private room    False       True         2
# 11   10   207.1488 Entire home/apt False       False        2
# 12   11   345.0927 Entire home/apt False       False        2
# 13   12   263.7711 Entire home/apt False       False        2
# 14   13   242.7999 Private room    False       True         2
# ...
